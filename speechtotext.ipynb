# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabhch6398/AdvAITriainingSecD/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create audio to text using model ehisper model and upload the code to github
